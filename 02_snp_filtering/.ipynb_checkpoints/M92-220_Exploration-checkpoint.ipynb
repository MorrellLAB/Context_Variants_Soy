# %%
import numpy as np
import scipy
import pandas
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('white')
sns.set_style('ticks')
sns.set_context('notebook')
import h5py
import allel; print('scikit-allel', allel.__version__)
# Out:
# scikit-allel 1.2.0

# %%
def plot_variant_hist(x, f, bins=30, xlim=100, neglim=0):
    fig, ax = plt.subplots(figsize=(7, 5))
    sns.despine(ax=ax, offset=10)
    ax.hist(x, bins=bins)
    ax.set_xlabel(f)
    ax.set_xlim(neglim, xlim)
    ax.set_ylabel('No. variants')
    ax.set_title('Variant %s distribution' % f)

# %% [markdown]
# ## FN 30

# %%
file = "/panfs/roc/groups/9/morrellp/shared/Projects/Context_Of_Mutations/FN30cat/Variant_Recalibrator/FN30CAT_30.vcf"

# %%
#allel.vcf_to_hdf5(file,
                  '/panfs/roc/groups/9/morrellp/shared/Projects/Context_Of_Mutations/FN30cat/Variant_Recalibrator/FN30CAT_30.h5',
                  fields='*',
                  overwrite=True)

# %%
callset = h5py.File('/panfs/roc/groups/9/morrellp/shared/Projects/Context_Of_Mutations/FN30cat/Variant_Recalibrator/FN30CAT_30.h5', mode='r')

# %%
variants = allel.VariantChunkedTable(callset['variants'], 
                                     names=['POS', 'REF', 'ALT', 'QUAL', 'DP', 'MQ', 'QD', 'AC', 'FS', 'ReadPosRankSum', 'MQRankSum'])

# %%
np.percentile(callset['calldata/DP'], 95)
# Out:
# 43.0

# %%
plot_variant_hist(callset['calldata/DP'][:,:].flatten(), 'DP', bins=1500)

# %%
plot_variant_hist(variants['QUAL'][:], 'QUAL', bins=10000, xlim=100000)

# %%
QD = variants['QD'][:]
cleanQD = QD[np.isfinite(QD)]
np.percentile(cleanQD, 10)
# Out:
# 1.9299999475479126

# %%
plot_variant_hist(variants['QD'][:], 'QD', xlim=50)
# Out:
# /home/morrellp/wyant008/.local/lib/python3.6/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/morrellp/wyant008/.local/lib/python3.6/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
np.percentile(callset['calldata/GQ'][:,:].flatten(), 15)
# Out:
# 9.0

# %%
plot_variant_hist(callset['calldata/GQ'][:,:].flatten(), 'GQ', bins=50, xlim=100)

# %%
np.percentile(variants['FS'][:], 95)
# Out:
# 75.27999877929688

# %%
plot_variant_hist(variants['FS'][:], 'FS', bins=500, xlim=70)

# %%
MQ = variants['MQRankSum'][:]
cleanMQ = MQ[np.isfinite(MQ)]
np.percentile(cleanMQ, 5)
# Out:
# -4.25600004196167

# %%
plot_variant_hist(variants['MQRankSum'][:], 'MQRankSum', bins=500, xlim=2, neglim=-6)
# Out:
# /home/morrellp/wyant008/.local/lib/python3.6/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/morrellp/wyant008/.local/lib/python3.6/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
RP = variants['ReadPosRankSum'][:]
cleanRP = RP[np.isfinite(RP)]
np.percentile(cleanRP, 10)
# Out:
# -0.9670000076293945

# %%
plot_variant_hist(variants['ReadPosRankSum'][:], 'ReadPosRankSum', bins=500, xlim=5, neglim=-5)
# Out:
# /home/morrellp/wyant008/.local/lib/python3.6/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/morrellp/wyant008/.local/lib/python3.6/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# ## M920-220

# %%
file = "/panfs/roc/groups/9/morrellp/shared/Projects/Context_Of_Mutations/M92-220/Genotype_GVCFs/M92-220_complete.vcf"

# %%
allel.vcf_to_hdf5(file,
                  '/panfs/roc/groups/9/morrellp/shared/Projects/Context_Of_Mutations/M92-220/Genotype_GVCFs/M92-220_complete.h5',
                  fields='*',
                  overwrite=True)

# %%
callset = h5py.File('/panfs/roc/groups/9/morrellp/shared/Projects/Context_Of_Mutations/M92-220/Genotype_GVCFs/M92-220_complete.h5', mode='r')

# %%
variants = allel.VariantChunkedTable(callset['variants'], 
                                     names=['POS', 'REF', 'ALT', 'QUAL', 'DP', 'MQ', 'QD', 'AC', 'FS', 'ReadPosRankSum', 'MQRankSum'])

# %%
np.percentile(callset['calldata/DP'], 95)
# Out:
# 121.0

# %%
plot_variant_hist(callset['calldata/DP'][:,:].flatten(), 'DP', bins=1500, xlim=300)

# %%
plot_variant_hist(variants['QUAL'][:], 'QUAL', bins=2000, xlim=15000)

# %%
plot_variant_hist(callset['calldata/GQ'][:,:].flatten(), 'GQ', bins=50, xlim=100)

# %%
np.percentile(variants['FS'][:], 95)
# Out:
# 31.757999420166016

# %%
plot_variant_hist(variants['FS'][:], 'FS', bins=500, xlim=70)

# %%
MQ = variants['MQRankSum'][:]
cleanMQ = MQ[np.isfinite(MQ)]
np.percentile(cleanMQ, 5)
# Out:
# -6.566999912261963

# %%
plot_variant_hist(variants['MQRankSum'][:], 'MQRankSum', bins=200, xlim=3, neglim=-7)
# Out:
# /home/morrellp/wyant008/.local/lib/python3.6/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/morrellp/wyant008/.local/lib/python3.6/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
RP = variants['ReadPosRankSum'][:]
cleanRP = RP[np.isfinite(RP)]
np.percentile(cleanRP, 10)
# Out:
# -1.628999948501587

# %%
plot_variant_hist(variants['ReadPosRankSum'][:], 'ReadPosRankSum', bins=500, xlim=5, neglim=-5)
# Out:
# /home/morrellp/wyant008/.local/lib/python3.6/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/morrellp/wyant008/.local/lib/python3.6/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# ## BL 107

# %%
file = "/panfs/roc/groups/9/morrellp/shared/Projects/Context_Of_Mutations/FN30cat/Variant_Recalibrator"

# %%
allel.vcf_to_hdf5(file,
                  '/panfs/roc/groups/9/morrellp/shared/Projects/Context_Of_Mutations/FN30cat/Variant_Recalibrator/FN30CAT_107.h5',
                  fields='*',
                  overwrite=True)

# %%
callset = h5py.File('/panfs/roc/groups/9/morrellp/shared/Projects/Context_Of_Mutations/FN30cat/Variant_Recalibrator/FN30CAT_107.h5', mode='r')

# %%
variants = allel.VariantChunkedTable(callset['variants'], 
                                     names=['POS', 'REF', 'ALT', 'DP', 'MQ', 'QD', 'AC'])

# %%
np.percentile(callset['calldata/DP'], 50)

# %%
np.percentile(callset['calldata/DP'], 95)

# %%
np.percentile(callset['calldata/DP'], 98)

# %%
plot_variant_hist(callset['calldata/DP'][:,:].flatten(), 'DP', bins=1500)

# %%
plot_variant_hist(callset['calldata/GQ'][:,:].flatten(), 'GQ', bins=50, xlim=100)

# %%
# %%bash
# jupyter nbconvert  --to=html 'Depth_Filtering_3.6.ipynb'
